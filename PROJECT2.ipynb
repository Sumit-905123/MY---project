# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# Load the Titanic dataset
titanic = pd.read_csv('gender_submission (1).csv')
titanic = pd.read_csv('test (1).csv')
titanic = pd.read_csv('train (1).csv')

# Display the first few rows of the dataset
titanic.head()
# Check for missing values
titanic.isnull().sum()
# Check for missing values
titanic.isnull().sum()
# Check data types
titanic.dtypes
# Convert 'Survived', 'Pclass', and 'Embarked' to category
titanic['Survived'] = titanic['Survived'].astype('category')
titanic['Pclass'] = titanic['Pclass'].astype('category')
titanic['Embarked'] = titanic['Embarked'].astype('category')
# Summary statistics
titanic.describe(include='all')
# Survived
sns.countplot(x='Survived', data=titanic)
plt.title('Survival Count')
plt.show()


# Sex
sns.countplot(x='Sex', data=titanic)
plt.title('Gender Count')
plt.show()

# Embarked
sns.countplot(x='Embarked', data=titanic)
plt.title('Port of Embarkation Count')
plt.show()
# Age
sns.histplot(titanic['Age'], kde=True)
plt.title('Age Distribution')
plt.show()

# Fare
sns.histplot(titanic['Fare'], kde=True)
plt.title('Fare Distribution')
plt.show()

# Survival by Sex
sns.countplot(x='Sex', hue='Survived', data=titanic)
plt.title('Survival by Gender')
plt.show()

# Survival by Age
sns.histplot(data=titanic, x='Age', hue='Survived', multiple='stack')
plt.title('Survival by Age')
plt.show()

# Survival by Embarked
sns.countplot(x='Embarked', hue='Survived', data=titanic)
plt.title('Survival by Port of Embarkation')
plt.show()

# Fare vs Survived
sns.boxplot(x='Survived', y='Fare', data=titanic)
plt.title('Fare vs Survival')
plt.show()
# Pairplot for numerical variables
sns.pairplot(titanic[['Age', 'Fare', 'Pclass', 'Survived']], hue='Survived')
plt.show()

# Heatmap for correlation matrix
corr_matrix = titanic.corr()
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()
# Out:
# C:\Users\KIIT\New folder\Anaconda\Lib\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)
# C:\Users\KIIT\New folder\Anaconda\Lib\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)
# C:\Users\KIIT\New folder\Anaconda\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\KIIT\New folder\Anaconda\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 51
#      48 plt.show()
#      50 # Survival by Sex
# ---> 51 sns.countplot(x='Sex', hue='Survived', data=titanic)
#      52 plt.title('Survival by Gender')
#      53 plt.show()
#
# File ~\New folder\Anaconda\Lib\site-packages\seaborn\categorical.py:2955, in countplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, width, dodge, ax, **kwargs)
#    2952 if ax is None:
#    2953     ax = plt.gca()
# -> 2955 plotter.plot(ax, kwargs)
#    2956 return ax
#
# File ~\New folder\Anaconda\Lib\site-packages\seaborn\categorical.py:1587, in _BarPlotter.plot(self, ax, bar_kws)
#    1585 """Make the plot."""
#    1586 self.draw_bars(ax, bar_kws)
# -> 1587 self.annotate_axes(ax)
#    1588 if self.orient == "h":
#    1589     ax.invert_yaxis()
#
# File ~\New folder\Anaconda\Lib\site-packages\seaborn\categorical.py:767, in _CategoricalPlotter.annotate_axes(self, ax)
#     764     ax.set_ylim(-.5, len(self.plot_data) - .5, auto=None)
#     766 if self.hue_names is not None:
# --> 767     ax.legend(loc="best", title=self.hue_title)
#
# File ~\New folder\Anaconda\Lib\site-packages\matplotlib\axes\_axes.py:322, in Axes.legend(self, *args, **kwargs)
#     204 @_docstring.dedent_interpd
#     205 def legend(self, *args, **kwargs):
#     206     """
#     207     Place a legend on the Axes.
#     208
#    (...)
#     320     .. plot:: gallery/text_labels_and_annotations/legend.py
#     321     """
# --> 322     handles, labels, kwargs = mlegend._parse_legend_args([self], *args, **kwargs)
#     323     self.legend_ = mlegend.Legend(self, handles, labels, **kwargs)
#     324     self.legend_._remove_method = self._remove_legend
#
# File ~\New folder\Anaconda\Lib\site-packages\matplotlib\legend.py:1361, in _parse_legend_args(axs, handles, labels, *args, **kwargs)
#    1357     handles = [handle for handle, label
#    1358                in zip(_get_legend_handles(axs, handlers), labels)]
#    1360 elif len(args) == 0:  # 0 args: automatically detect labels and handles.
# -> 1361     handles, labels = _get_legend_handles_labels(axs, handlers)
#    1362     if not handles:
#    1363         log.warning(
#    1364             "No artists with labels found to put in legend.  Note that "
#    1365             "artists whose label start with an underscore are ignored "
#    1366             "when legend() is called with no argument.")
#
# File ~\New folder\Anaconda\Lib\site-packages\matplotlib\legend.py:1291, in _get_legend_handles_labels(axs, legend_handler_map)
#    1289 for handle in _get_legend_handles(axs, legend_handler_map):
#    1290     label = handle.get_label()
# -> 1291     if label and not label.startswith('_'):
#    1292         handles.append(handle)
#    1293         labels.append(label)
#
# AttributeError: 'int' object has no attribute 'startswith'
